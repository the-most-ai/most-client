# %%
import os
import sys
from pathlib import Path
sys.path.append('../')
from most import MostClient

# %%
client_id="67b3c833fd9d8fbca19cef01"
client_secret="nPOeE.JcS.ldy3mv9b6Xkg$wdTEpoBB/fX9oR3YXPE7xmEC4mrOOjZck4FwN6UmLek"
model_id="most-67b3cc701509ae033f0f9471"

# %%
client = MostClient(client_id=client_id, 
                    client_secret=client_secret,
                    model_id=model_id)

# %%
problem_ids = ['67bc166d748956b6cc27d564', '67bc1671748956b6cc27d74e', '67bc167d748956b6cc27e335']

# %%
client.fetch_results(problem_ids[0])
# Out:
# Result(id='67bc166d748956b6cc27d564', text=None, url='https://bc2cf9a7-70b1-41f2-88ad-a47588b0eaa0.selstorage.ru/2025/1/28/2025-01-28-15:39:30_755_79118333330_MjI3MzkyNzA2MTg=.mp3', results=None)

# %%
client.apply(problem_ids[1])
# Out:
# Result(id='67bc1671748956b6cc27d74e', text='', url='https://bc2cf9a7-70b1-41f2-88ad-a47588b0eaa0.selstorage.ru/2025/1/29/2025-01-29-09:58:38_1209_998909100040_MjI3NDM3NjYzMTU=.mp3', results=[ColumnResult(name='Приветствие и выявление потребностей', subcolumns=[SubcolumnResult(name='Озвучил компанию, должность, и представился (сделал это внятно и разборчиво)', score=2, description='Менеджер представился и озвучил компанию: "Здравствуйте, меня зовут Алексей, я менеджер мебельного магазина Диван.ру". Это подтверждает, что правило выполнено частично.'), SubcolumnResult(name='Уточнил имя клиента и обратился по имени более 2 раз за разговор', score=0, description='Менеджер не узнал имя клиента в ходе диалога. В транскрипции отсутствуют упоминания имени клиента.'), SubcolumnResult(name='Задал не менее трёх вопросов на выявление потребностей, чтобы убедиться, что товар подходит клиенту', score=2, description='В ходе диалога менеджер задавал вопросы для выявления потребностей клиента. Наприме
# ...

# %%
client.store_info(problem_ids[0], {"key": "value"})
# Out:
# StoredAudioData(id='67bc166d748956b6cc27d564', data={'key': 'value'})

# %%
client.fetch_info(problem_ids[0])
# Out:
# StoredAudioData(id='67bc166d748956b6cc27d564', data={'key': 'value'})
