# %%
import os
import sys
from pathlib import Path
import pprint
sys.path.append('../')
from most import MostClient

# %%
client = MostClient()

# %%
client.list_audios()[0]
# Out:
# Audio(id='67c70fc59c48436509d68917', url='https://cdn.the-most.ai/mostai/6758b5c46076f3c68f34ef87/01je90q4d0gmvqtvnnt2njs3hb.mp3')

# %%
pprint.pprint(client.get_score_modifier())
# Out:
# ScoreCalculation(score_mapping=[ScriptScoreMapping(column='Этап 1. '
#                                                           'Установление '
#                                                           'контакта',
#                                                    subcolumn='Знакомство',
#                                                    from_score=0,
#                                                    to_score=0),
#                                 ScriptScoreMapping(column='Этап 1. '
#                                                           'Установление '
#                                                           'контакта',
#                                                    subcolumn='Знакомство',
#                                                    from_score=1,
#                                                    to_score=5),
#                                 ScriptScoreMapping(column='Этап 1. '
# ...

# %%
results = client.apply("67c70fc59c48436509d68917", modify_scores=True)

# %%
pprint.pprint(results)
# Out:
# Result(id='67c70fc59c48436509d68917',
#        text='Спикер А: Ага, здравствуйте, Ирина, это Сергей академик Сигма! Вы '
#             'интересовались обучением по направлению?\n'
#             'Спикер Б: Еще раз.\n'
#             'Спикер А: По какому?\n'
#             'Спикер Б: Направлению Внешнеэкономическая деятельность.\n'
#             'Спикер А: Бизнес Китая, ага, ага актуально да было?\n'
#             'Спикер Б: Да, да, да, да?\n'
#             'Спикер А: Я вот хотел сориентировать по программе обучения пару '
#             'вопросов, задать, чтобы понять суть вашей цели, обсудим с вами '
#             'программу, чтобы. Убедиться, что она максимально соответствует '
#             'вашему ожиданию. И если что подойдет, я расскажу вариант в '
#             'процессе зачисления на курс, согласны? Угу, Угу, хорошо, тогда '
#             'они могли бы рассказать о себе в сфере деятельности. Как то уже с '
#             'этим направлением работаете или вы с 0 планируете нет?\n'
# ...
