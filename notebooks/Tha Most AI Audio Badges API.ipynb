# %%
import os
from datetime import datetime

from most import Badge, AsyncBadge
import dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
badge = Badge.create()
print("ed25519 keypair with b64 encoded public and private keys: ")
print("PUBLIC_KEY_B64: ", badge.sn)
print("PRIVATE_KEY_B64: ", badge.private_key)
print("Look into ./most/utils.py for more details")
# Out:
# ed25519 keypair with b64 encoded public and private keys:
# PUBLIC_KEY_B64:  hjFNIalYL6rJFeBBuTkp/bDVMajKYuKdusCZDW2PA4M=
# PRIVATE_KEY_B64:  Vg4B+x7HieO4/cA9GxukWDS7MTPV7mJIB2oxedGrVOk=
# Look into ./most/utils.py for more details

# %%
print("Registering device with admin API key:")
badge.admin_api_key = os.getenv("MOST_BADGE_ADMIN_API_KEY")
print("We need register our device one time. After registration badge id will be saved in badge object.")
print(badge.register())
# Out:
# Registering device with admin API key:
# We need register our device one time. After registration badge id will be saved in badge object.
# 695641b144c1a50af01b541d

# %%
badge = Badge(sn="hjFNIalYL6rJFeBBuTkp/bDVMajKYuKdusCZDW2PA4M=",
              private_key="Vg4B+x7HieO4/cA9GxukWDS7MTPV7mJIB2oxedGrVOk=")

# %%
badge.obtain_badge_id()
# Out:
# '695641b144c1a50af01b541d'

# %%
badge.is_registered()
# Out:
# True

# %%
badge.login()

# %%
print("Obtained token: ")
print(badge.token)
# Out:
# Obtained token:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJiYWRnZV9pZCI6IjY5NTY0MWIxNDRjMWE1MGFmMDFiNTQxZCIsImV4cCI6MTc2NzMwNDk5N30.BMIaXdgQ7Ecuc5J7yYxUVyVXM6FSY4bM72Ye9EgsZv0

# %%
print("And now we can upload audio files:")
# Out:
# And now we can upload audio files:

# %%
badge.upload_audio("/Users/kaspar_george/Downloads/rerooms_example.mp3",
                   start_dt=datetime(2025, 12, 25, 12, 0),
                   end_dt=datetime(2025, 12, 25, 13, 10))
# Out:
# Audio(id='6956eeee44c1a50af044a8ec', url='https://cdn.the-most.ai/mostai/69560abb44c1a50af013deac/rerooms_example.mp3')
